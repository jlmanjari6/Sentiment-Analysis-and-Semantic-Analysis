# %%
# Extracting tweets from search api

from tweepy import OAuthHandler
from twitter_credentials import Tokens
import tweepy as twp

auth = OAuthHandler(Tokens.CONSUMER_KEY, Tokens.CONSUMER_SECRET)
auth.set_access_token(Tokens.ACCESS_TOKEN, Tokens.ACCESS_TOKEN_SECRET)

api = twp.API(auth)

tweets_info = twp.Cursor(api.search,
                             q=('Canada OR Canada+import OR Canada+export OR Canada+vehicle+sales OR Canada+Education'),
                             lang="en", 
                             tweet_mode="extended").items(2000)

# %%
#clean the tweets by removing URLs, emoticons and, special characters except '-' and '+' because, in few cases 
#they decide the polarity of the word. Example: absent-minded, anti-nationalist  
#Also, extracted the extended text of each tweet

import re

list_tweets = []

for item in tweets_info:    
    # to retrieve the full text of each tweet
    if 'retweeted_status' in item._json:
        tweet = item._json['retweeted_status']['full_text']
    else:
        tweet = item.full_text
        
    tweet_no_url = re.sub(r"http\S+", "", tweet) #remove URLs
    tweet_no_emoji= re.compile('[\U00010000-\U0010ffff]', flags=re.UNICODE).sub(r'', tweet_no_url) #remove emoticons        
    cleaned_tweet = re.sub('[^A-Za-z0-9\+\- ]+', '', tweet_no_emoji) #remove special characters
   
    list_tweets.append(cleaned_tweet) #adding cleaned tweets to a list

# %%
# creating bag of words for each tweet and store in dictionary that contains tweets and the corresponding list of bag of words

dic={}
counter=1
for tweet in list_tweets:    
    list = []    
    list = tweet.split()    
    bag_of_words = {}
    for word in list:        
        if word in bag_of_words:
             bag_of_words[word] = bag_of_words[word] + 1
        else: 
             bag_of_words[word] = 1
               
    dic[tweet] = bag_of_words       
    counter += 1

# %%
# using the Lexicon opinion set of positive and negative words to perform sentiment analysis

fileNegative = open('negative-words.txt', 'r')
filePositive = open('positive-words.txt', 'r')

content_fileNegative = fileNegative.read()
content_filePositive = filePositive.read()

negative_file_list = content_fileNegative.split()
positive_file_list = content_filePositive.split()

# %%
# looping through the dictionary created above to find the polarity of each tweet in the dictionary
# created dataframe to show the results 

import pandas as pd
df = pd.DataFrame(columns=['Tweet', 'Message', 'Match', 'Polarity'])

count_tweets = 0

tweet_list = dic.keys()    
for tweet in tweet_list:
    count_negative = 0
    count_positive = 0
    count_neutral = 0  
    negative_list = []
    positive_list = []
    
    bag_of_words_dic = dic[tweet]
    bag_of_words_dic_keys = bag_of_words_dic.keys()    
    for word in bag_of_words_dic_keys:
        increment = bag_of_words_dic[word]
        if word in negative_file_list:          
            count_negative += increment
            negative_list.append(word)
        elif word in positive_file_list:
            count_positive += increment
            positive_list.append(word)
        
    if count_negative > count_positive:        
        df.loc[count_tweets] = [count_tweets+1, tweet, negative_list, 'NEGATIVE' ]
    elif count_negative < count_positive:
        df.loc[count_tweets] = [count_tweets+1, tweet, positive_list, 'POSITIVE']
    else:
        df.loc[count_tweets] = [count_tweets+1, tweet, '-', 'NEUTRAL']
        
    count_tweets += 1

# %%
#printing the resultant data frame
df
# Out:
#      Tweet                                            Message  \
# 0        1  She said the man was standing in the middle of...
# 1        2  Everyday tHe DiAsPoRa NeEd To ClAiM BRiTaiN Ca...
# 2        3  NSW police aid victims families in Canada foll...
# 3        4  Just ordered PapaJohns Use promo code PAPATRAC...
# 4        5  David thompson marfred art IN THE SADDLE 2SASK...
# 5        6  Canadian police can tolerate abortion parades ...
# 6        7  Amazing atmosphere here in DC as Prime Ministe...
# 7        8  The UKs handling of trade talks with Canada do...
# 8        9  dominicapold ppclondonwest kenpro11 Brianevera...
# 9       10  O-Red choked in the 2nd amp 3rd Danny starts t...
# 10      11  Saw board of Canada releases and almost shit m...
# 11      12   Canada Ranked The 1 Freest Country In The World
# 12      13  Niagara Falls is experiencing EXTREME HEAT yet...
# 13      14  Food Trucks Trailers amp Restaurants Wanted He...
# 14      15  RobertVosFrere My daughter thought might be Ca...
# 15      16  CanadensisMax You are clearly on your own Get ...
# 16      17  Someone called the police on an icecream truck...
# 17      18  Suicide hotline numbers  United Kingdom  116 1...
# 18      19  Number of Minecraft servers 2019US 42593German...
# 19      20  canada has become my new favourite place on ea...
# 20      21  Gerald Butts is a cancer to CanadaHis entire l...
# 21      22  Program makes science and math fun and relevan...
# 22      23  Yoho National Park and Rocky Mountains in Brit...
# 23      24  1 Webinar Wed Aug 7 1030 CST UTC -6 Ian Stavne...
# 24      25        Trending in Canada as well  PMIKJalsaInUSA
# 25      26  Saarbo1 NZ farners maybe far more out of touch...
# 26      27  MichelleRempel blocked me because I questioned...
# 27      28  Interesting part of Canadian history and Apoll...
# 28      29  On Saturday 20th July myself and the Ghana Hig...
# 29      30      I just found out Canada isnt real via rJokes
# ...    ...                                                ...
# 1203  1204  If you want to make boatloads of money move to...
# 1204  1205         Measles in Montreal what you should know
# 1205  1206  christopstewart StephanieKelton We can say you...
# 1206  1207  dadzez Hard to believe a person who doesnt lik...
# 1207  1208  glibcf EleanoraHorTa valorthief gnoll110 julia...
# 1208  1209  Congratulations to EnsanFilms Ambassador ASSEM...
# 1209  1210  Politicians if youre not going to respond to d...
# 1210  1211  CosmicSlice Pennyvane10 The Canada Food Guide ...
# 1211  1212  And all of that is untrue US spends more per c...
# 1212  1213  Not all storms come to disrupt your life some ...
# 1213  1214  A federal politician blocked me because I doub...
# 1214  1215  jaevionn Teachers being recruited by USA Canad...
# 1215  1216  Soob Dude its the capital city of the Yukon te...
# 1216  1217  Rihannas 1 singles around the world main chart...
# 1217  1218  Quebecs new law on religious symbols makes min...
# 1218  1219  SuperDaStar you and your fucking tea and your ...
# 1219  1220  MichelleRempel Your rant proves just how ignor...
# 1220  1221  VON Canada is looking for teammates like you S...
# 1221  1222  We Pakistanis here in Pakistan at this time SA...
# 1222  1223  Doug Ford is an embarrassment to the city of T...
# 1223  1224  Obama gave a coherent message to the hate squa...
# 1224  1225  Can we please remember that CPC leader Andrew ...
# 1225  1226  If you tell snowflake Michelle Rempel to leave...
# 1226  1227  jdouglaslittle patrickgs11 ProspectGeek TracyJ...
# 1227  1228  SFF180 CNN Im in Canada We are total commie up...
# 1228  1229  Capitalism is so great that it1 Creates homele...
# 1229  1230  DanielH85442891 ITSLIISA calybo62 palevell Hed...
# 1230  1231  refugee613 ccrweb AmnestyNow CARLadvocates We ...
# 1231  1232  from8tolying8 They are smuggling drugs and run...
# 1232  1233  Hey NunyaJim if I had a friend coming through ...
#
#                                  Match  Polarity
# 0                                    -   NEUTRAL
# 1                             [better]  POSITIVE
# 2                             [murder]  NEGATIVE
# 3                                    -   NEUTRAL
# 4                                    -   NEUTRAL
# 5                                    -   NEUTRAL
# 6                                    -   NEUTRAL
# 7                               [well]  POSITIVE
# 8                                    -   NEUTRAL
# 9                                    -   NEUTRAL
# 10                              [shit]  NEGATIVE
# 11                                   -   NEUTRAL
# 12                                   -   NEUTRAL
# 13                              [best]  POSITIVE
# 14                                   -   NEUTRAL
# 15                           [clearly]  POSITIVE
# 16                                   -   NEUTRAL
# 17                     [dies, suicide]  NEGATIVE
# 18                                   -   NEUTRAL
# 19                                   -   NEUTRAL
# 20                  [cancer, terrible]  NEGATIVE
# 21                               [fun]  POSITIVE
# 22                               [fun]  POSITIVE
# 23                                   -   NEUTRAL
# 24                              [well]  POSITIVE
# 25                                   -   NEUTRAL
# 26                     [poorly, trick]  NEGATIVE
# 27                                   -   NEUTRAL
# 28                       [celebration]  POSITIVE
# 29                                   -   NEUTRAL
# ...                                ...       ...
# 1203                            [good]  POSITIVE
# 1204                                 -   NEUTRAL
# 1205                                 -   NEUTRAL
# 1206                            [like]  POSITIVE
# 1207           [hate, crime, disagree]  NEGATIVE
# 1208                                 -   NEUTRAL
# 1209                                 -   NEUTRAL
# 1210                          [afford]  POSITIVE
# 1211                          [untrue]  NEGATIVE
# 1212                                 -   NEUTRAL
# 1213                 [extraordinarily]  POSITIVE
# 1214                                 -   NEUTRAL
# 1215                                 -   NEUTRAL
# 1216                                 -   NEUTRAL
# 1217                      [like, lead]  POSITIVE
# 1218                         [fucking]  NEGATIVE
# 1219            [rant, ignorant, hate]  NEGATIVE
# 1220                            [like]  POSITIVE
# 1221                           [bless]  POSITIVE
# 1222            [embarrassment, shame]  NEGATIVE
# 1223                                 -   NEUTRAL
# 1224                          [racist]  NEGATIVE
# 1225                                 -   NEUTRAL
# 1226  [mediocrity, problems, pathetic]  NEGATIVE
# 1227                                 -   NEUTRAL
# 1228                           [great]  POSITIVE
# 1229             [well, solid, proven]  POSITIVE
# 1230                       [suffering]  NEGATIVE
# 1231                                 -   NEUTRAL
# 1232                                 -   NEUTRAL
#
# [1233 rows x 4 columns]

# %%
# export output to csv
df.to_csv("sentiment_output.csv", encoding='utf-8', index=False)
